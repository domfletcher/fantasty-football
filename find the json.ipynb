# %%
import os
import datetime

# %%
os.chdir('C:\Users\Dom\\Documents\\GitHub\\fantasypl_stats\\data')

# %%
f = []
for (dirpath, dirnames, filenames) in os.walk('C:\Users\Dom\\Documents\\GitHub\\fantasypl_stats\\data'):
    f.extend(filenames)

# %%
n = 1
for x in f:
    print x[8:18],x,datetime.datetime.fromtimestamp(int(x[8:18])).strftime('%Y-%m-%d')
    os.rename(x, 'players.'+datetime.datetime.fromtimestamp(int(x[8:18])).strftime('%Y-%m-%d')+' '+ str(n) + '.json')
    n = n+ 1
# Out:
# 1424136927 players.1424136927.json 2015-02-17
# 1424180192 players.1424180192.json 2015-02-17
# 1424181979 players.1424181979.json 2015-02-17
# 1424189156 players.1424189156.json 2015-02-17
# 1424192824 players.1424192824.json 2015-02-17
# 1424196371 players.1424196371.json 2015-02-17
# 1424203571 players.1424203571.json 2015-02-17
# 1424210768 players.1424210768.json 2015-02-17
# 1424217970 players.1424217970.json 2015-02-18
# 1424229997 players.1424229997.json 2015-02-18
# 1424232376 players.1424232376.json 2015-02-18
# 1424239566 players.1424239566.json 2015-02-18
# 1424246769 players.1424246769.json 2015-02-18
# 1424253971 players.1424253971.json 2015-02-18
# 1424261179 players.1424261179.json 2015-02-18
# 1424268370 players.1424268370.json 2015-02-18
# 1424275568 players.1424275568.json 2015-02-18
# 1424282776 players.1424282776.json 2015-02-18
# 1424289977 players.1424289977.json 2015-02-18
# 1424297167 players.1424297167.json 2015-02-18
# ...
